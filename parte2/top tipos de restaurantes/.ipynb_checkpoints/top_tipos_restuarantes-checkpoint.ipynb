# %%
import pandas as pd
from typing import List, Dict
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("restaurantes_con_distrito_barrio.csv", index_col = 0)
df
# Out:
#                          Name  \
# id
# 1         Freedom Cakes Diner
# 2      Mad Mad Vegan - Chueca
# 3           Frutas Prohibidas
# 4    Mad Mad Vegan - Lavapiés
# 5               Flower Burger
# ..                        ...
# 744     Morgano Crafted Beers
# 745          Adagio Gelateria
# 746          La Huella Vegana
# 747                    Kamado
# 748    Sibuya Urban Sushi Bar
#
#                                                Address        Lat      Long  \
# id
# 1                     Calle Cádiz 7,Madrid,Spain,28004  40.415876 -3.702805
# 2                   Calle Pelayo 19,Madrid,Spain,28004  40.422698 -3.698609
# 3         Calle del Conde Duque, 26,Madrid,Spain,28015  40.427467 -3.710349
# 4                       Lavapiés 16,Madrid,Spain,28012  40.411113 -3.703039
# 5        Calle Luchana 13, Chamberí,Madrid,Spain,28010  40.430001 -3.701037
# ..                                                 ...        ...       ...
# 744  Alamo 2, Boadilla del Monte, Madrid, Spain, 28660  40.405759 -3.876917
# 745  Avenida de Adolfo Suárez, 7, Boadilla Del Mont...  40.405413 -3.876999
# 746  Calle de las Trece Rosas, 2,Rivas-vaciamadrid,...  40.376390 -3.540020
# 747  Calle Oslo 53CC (at  X-Madrid Shopping Center)...  40.341716 -3.847447
# 748  C Oslo, 53 X, Local 38 (at X-Madrid),Madrid,Sp...  40.340854 -3.848026
#
#      Number of Ratings  Restaurant Rating               Type of Restaurant  \
# id
# 1                470.0                4.5                ['International']
# 2                410.0                5.0          ['American', 'Mexican']
# 3                241.0                5.0      ['International', 'Fusion']
# 4                216.0                4.5          ['American', 'Mexican']
# 5                 14.0                4.5          ['American', 'Western']
# ..                 ...                ...                              ...
# 744                1.0                4.0    ['Middle Eastern', 'Spanish']
# 745                1.0                4.0                      ['Italian']
# 746               31.0                4.5           ['Western', 'Spanish']
# 747                3.0                2.5                        ['Asian']
# 748                1.0                4.0  ['Japanese', 'Asian', 'Fusion']
#
#      Number of Bookmarks     Price Range   Phone Number  \
# id
# 1                    766        Moderado  +34-910741347
# 2                    612        Moderado  +34-914442077
# 3                    555        Moderado  +34-911525533
# 4                    465        Moderado  +34-910665299
# 5                     47          Barato  +34-910328968
# ..                   ...             ...            ...
# 744                    2          Barato  +34-695635423
# 745                    0  No price range  +34-912859853
# 746                   42        Moderado  +34-917139958
# 747                    2        Moderado  +34-917374775
# 748                    0        Moderado  +34-917374710
#
#                                   Website  \
# id
# 1             http://www.freedomcakes.es/
# 2                https://madmadvegan.com/
# 3        http://www.frutasprohibidas.com/
# 4                https://madmadvegan.com/
# 5            https://www.flowerburger.it/
# ..                                    ...
# 744                            No website
# 745                            No website
# 746        http://www.lahuellavegana.com/
# 747            http://kamadoasianfood.es/
# 748  https://www.sibuyaurbansushibar.com/
#
#                                            Instagram  \
# id
# 1              http://www.instagram.com/freedomcakes
# 2               http://www.instagram.com/madmadvegan
# 3       http://www.instagram.com/frutasprohibidasbar
# 4               http://www.instagram.com/madmadvegan
# 5           http://www.instagram.com/flowerburger_es
# ..                                               ...
# 744                                     No instagram
# 745         http://www.instagram.com/adagiogelateria
# 746                                     No instagram
# 747                                     No instagram
# 748  http://www.instagram.com/sibuya_urban_sushi_bar
#
#                                     Facebook  \
# id
# 1      http://facebook.com/Freedomcakesvegan
# 2            http://facebook.com/MADMADVEGAN
# 3    http://facebook.com/frutasprohibidasbar
# 4            http://facebook.com/MADMADVEGAN
# 5        http://facebook.com/flowerburger.it
# ..                                       ...
# 744  http://facebook.com/MorganoCraftedBeers
# 745      http://facebook.com/adagiogelateria
# 746       http://facebook.com/lahuellavegana
# 747      http://facebook.com/Kamadoasianfood
# 748     http://facebook.com/sibuyaurbansushi
#
#                                              Timetable  \
# id
# 1    {'Monday': '08:00 - 00:00', 'Tuesday': '08:00 ...
# 2    {'Monday': '13:00 - 00:00', 'Tuesday': '13:00 ...
# 3    {'Monday': 'Closed', 'Tuesday': 'Closed', 'Wed...
# 4    {'Monday': '13:00 - 00:00', 'Tuesday': '13:00 ...
# 5    {'Monday': '13:00 - 16:30, 19:30 - 23:30', 'Tu...
# ..                                                 ...
# 744  {'Monday': '19:00 - 01:00', 'Tuesday': '19:00 ...
# 745  {'Monday': '10:00 - 22:30', 'Tuesday': '10:00 ...
# 746  {'Monday': '08:30 - 23:00', 'Tuesday': '08:30 ...
# 747  {'Monday': '13:00 - 16:00, 20:00 - 23:00', 'Tu...
# 748  {'Monday': '13:00 - 16:00, 20:00 - 23:00', 'Tu...
#
#                                                    url NOMBRE_DISTRITO  \
# id
# 1    https://www.happycow.net/reviews/freedom-cakes...          Centro
# 2    https://www.happycow.net/reviews/mad-mad-madri...          Centro
# 3    https://www.happycow.net/reviews/frutas-prohib...          Centro
# 4    https://www.happycow.net/reviews/mad-mad-vegan...          Centro
# 5    https://www.happycow.net/reviews/flower-burger...        Chamberi
# ..                                                 ...             ...
# 744  https://www.happycow.net/reviews/morgano-craft...             NaN
# 745  https://www.happycow.net/reviews/adagio-gelate...             NaN
# 746  https://www.happycow.net/reviews/la-huella-riv...             NaN
# 747  https://www.happycow.net/reviews/kamado-alcorc...             NaN
# 748  https://www.happycow.net/reviews/sibuya-urban-...             NaN
#
#     NOMBRE_BARRIO
# id
# 1             Sol
# 2        Justicia
# 3     Universidad
# 4     Embajadores
# 5      Ríos Rosas
# ..            ...
# 744           NaN
# 745           NaN
# 746           NaN
# 747           NaN
# 748           NaN
#
# [749 rows x 17 columns]

# %%
import pandas as pd
from typing import List, Dict

tipos_restaurantes: List[str] = [
    "Korean", "African", "American", "Asian", "Australian", "Brazilian", "British", 
    "Caribbean", "Chinese", "European", "French", "Fusion", "German", "Indian", 
    "International", "Italian", "Japanese", "Latin", "Mediterranean", "Mexican", 
    "Middle Eastern", "Spanish", "Taiwanese", "Thai", "Vietnamese", "Western"
]

total_tipos: Dict[str, Dict[str, float]] = {}
transform_prices = {
    "Barato": 1,
    "Moderado": 2,
    "Caro": 3,
    "No price range": 0
}
# Modificamos los precios para otorgarles un valor numérico

df = df.replace(transform_prices)

for tipo in tipos_restaurantes:
    filtro_tipo = df[df["Type of Restaurant"].str.contains(tipo, case=False, na=False)].copy()
    # Seleccionamos aquellos restaurantes que contengan en su lista de tipos, el tipo pedido
    
    conteo_distritos = filtro_tipo["NOMBRE_DISTRITO"].value_counts()
    conteo_barrio = filtro_tipo["NOMBRE_BARRIO"].value_counts()

    distrito_mas_frecuente = conteo_distritos.idxmax()
    barrio_mas_frecuente = conteo_barrio.idxmax()
    # Selección del distrito y del barrio que más aparece

    numero_tipo = len(filtro_tipo)
    numero_reviews = int(filtro_tipo["Number of Ratings"].sum())

    if numero_reviews > 0:
        distribucion = (filtro_tipo["Number of Ratings"] / numero_reviews) * filtro_tipo["Restaurant Rating"]
        media_ponderada = round(distribucion.sum(), 3)
    else:
        media_ponderada = 0
    # Hacer la media ponderada de los ratings

    valid_prices = filtro_tipo[filtro_tipo["Price Range"] != 0]["Price Range"]
    #Selección de sólo aquellos restaurantes que especifican el precio

    if len(valid_prices) > 0:
        media_precios = (round(valid_prices.sum() / len(valid_prices)))
    else:
        media_precios = 0
    # Media de los precios y redondeando al entero más cercano

    total_tipos[tipo] = {
        "total": numero_tipo,
        "reviews": numero_reviews,
        "MP rating": media_ponderada,
        "Media precio": media_precios,
        "Distrito más frecuente": distrito_mas_frecuente,
        "Barrio más frecuente": barrio_mas_frecuente
    }

df_total_tipos = pd.DataFrame.from_dict(total_tipos)
transform = {
    1: "Barato",
    2: "Moderado",
    3: "Caro"
}

df_mod_media_precios = df_total_tipos.T[["Media precio"]].replace(transform)
df_mod_media_precios.T
df_transpose = df_total_tipos.T
df_transpose["Media Precios"] = df_mod_media_precios
df_def = df_transpose.drop(columns="Media precio")

df_def

df_def.to_csv("df_tipos")

# %%
total_reviews_ordenados = df_def.sort_values("reviews", ascending=False)
total_reviews_ordenados[:10]
# Out:
#               total reviews MP rating Distrito más frecuente  \
# Spanish         227    4898     4.419                 Centro
# International   101    2370     4.403                 Centro
# Mediterranean   120    2351     4.397                 Centro
# Western          80    1558     4.437                 Centro
# Fusion           61    1519     4.431                 Centro
# American         85    1356      4.49                 Centro
# European        124    1241     4.164                 Centro
# Italian          86    1078     4.565                 Centro
# Mexican          37    1006     4.572                 Centro
# Asian            86     412     3.823                 Centro
#
#               Barrio más frecuente Media Precios
# Spanish                Embajadores      Moderado
# International          Embajadores      Moderado
# Mediterranean          Embajadores      Moderado
# Western                Universidad      Moderado
# Fusion                 Universidad      Moderado
# American               Universidad      Moderado
# European               Embajadores      Moderado
# Italian                Embajadores      Moderado
# Mexican                   Justicia      Moderado
# Asian                  Embajadores      Moderado

# %%
total_reviews_ordenados[-10:]
# Out:
#            total reviews MP rating Distrito más frecuente  \
# African        7      25      3.92                 Centro
# Indian         7      22     3.818                 Centro
# French         6      19     3.211                 Centro
# Australian     2      18     3.806                 Centro
# Taiwanese      1      13       3.5                 Centro
# Korean         4      10       3.4                 Centro
# Caribbean      3       5       3.2                 Centro
# Vietnamese     3       5       3.6                 Centro
# German         2       1       4.0              Vicalvaro
# British        1       0         0                 Centro
#
#                     Barrio más frecuente Media Precios
# African                      Embajadores      Moderado
# Indian                       Embajadores      Moderado
# French                       Universidad        Barato
# Australian                       Palacio      Moderado
# Taiwanese                         Cortes        Barato
# Korean                           Palacio      Moderado
# Caribbean                        Palacio        Barato
# Vietnamese                   Embajadores      Moderado
# German      Casco Histórico de Vicálvaro      Moderado
# British                      Universidad      Moderado

# %%
total_tipos_ordenados = df_def.sort_values("total", ascending=False)
total_tipos_ordenados[:10]
# Out:
#               total reviews MP rating Distrito más frecuente  \
# Spanish         227    4898     4.419                 Centro
# European        124    1241     4.164                 Centro
# Mediterranean   120    2351     4.397                 Centro
# International   101    2370     4.403                 Centro
# Italian          86    1078     4.565                 Centro
# Asian            86     412     3.823                 Centro
# American         85    1356      4.49                 Centro
# Western          80    1558     4.437                 Centro
# Fusion           61    1519     4.431                 Centro
# Japanese         54     271     3.873                 Centro
#
#               Barrio más frecuente Media Precios
# Spanish                Embajadores      Moderado
# European               Embajadores      Moderado
# Mediterranean          Embajadores      Moderado
# International          Embajadores      Moderado
# Italian                Embajadores      Moderado
# Asian                  Embajadores      Moderado
# American               Universidad      Moderado
# Western                Universidad      Moderado
# Fusion                 Universidad      Moderado
# Japanese                  Justicia      Moderado

# %%
total_tipos_ordenados[-10:]
# Out:
#            total reviews MP rating Distrito más frecuente  \
# African        7      25      3.92                 Centro
# French         6      19     3.211                 Centro
# Thai           5      26       3.5                 Centro
# Korean         4      10       3.4                 Centro
# Caribbean      3       5       3.2                 Centro
# Vietnamese     3       5       3.6                 Centro
# German         2       1       4.0              Vicalvaro
# Australian     2      18     3.806                 Centro
# British        1       0         0                 Centro
# Taiwanese      1      13       3.5                 Centro
#
#                     Barrio más frecuente Media Precios
# African                      Embajadores      Moderado
# French                       Universidad        Barato
# Thai                                 Sol      Moderado
# Korean                           Palacio      Moderado
# Caribbean                        Palacio        Barato
# Vietnamese                   Embajadores      Moderado
# German      Casco Histórico de Vicálvaro      Moderado
# Australian                       Palacio      Moderado
# British                      Universidad      Moderado
# Taiwanese                         Cortes        Barato

# %%
total_rating_ordenados = df_def.sort_values("MP rating", ascending=False)
total_rating_ordenados[:10]
# Out:
#                total reviews MP rating Distrito más frecuente  \
# Middle Eastern    34     335     4.578                 Centro
# Mexican           37    1006     4.572                 Centro
# Brazilian          8      35     4.571                 Centro
# Italian           86    1078     4.565                 Centro
# American          85    1356      4.49                 Centro
# Western           80    1558     4.437                 Centro
# Fusion            61    1519     4.431                 Centro
# Spanish          227    4898     4.419                 Centro
# International    101    2370     4.403                 Centro
# Mediterranean    120    2351     4.397                 Centro
#
#                Barrio más frecuente Media Precios
# Middle Eastern          Universidad      Moderado
# Mexican                    Justicia      Moderado
# Brazilian                  Justicia      Moderado
# Italian                 Embajadores      Moderado
# American                Universidad      Moderado
# Western                 Universidad      Moderado
# Fusion                  Universidad      Moderado
# Spanish                 Embajadores      Moderado
# International           Embajadores      Moderado
# Mediterranean           Embajadores      Moderado

# %%
total_rating_ordenados[-10:]
# Out:
#            total reviews MP rating Distrito más frecuente  \
# Indian         7      22     3.818                 Centro
# Australian     2      18     3.806                 Centro
# Chinese       19     246     3.803                 Centro
# Vietnamese     3       5       3.6                 Centro
# Taiwanese      1      13       3.5                 Centro
# Thai           5      26       3.5                 Centro
# Korean         4      10       3.4                 Centro
# French         6      19     3.211                 Centro
# Caribbean      3       5       3.2                 Centro
# British        1       0         0                 Centro
#
#            Barrio más frecuente Media Precios
# Indian              Embajadores      Moderado
# Australian              Palacio      Moderado
# Chinese                     Sol        Barato
# Vietnamese          Embajadores      Moderado
# Taiwanese                Cortes        Barato
# Thai                        Sol      Moderado
# Korean                  Palacio      Moderado
# French              Universidad        Barato
# Caribbean               Palacio        Barato
# British             Universidad      Moderado

# %%
plt.xticks(rotation=90)
plt.bar(total_tipos_ordenados.index, total_tipos_ordenados["total"])
plt.title("Número de restaurantes")
# Out:
# Text(0.5, 1.0, 'Número de restaurantes')

# %%
plt.xticks(rotation=90)
plt.bar(total_rating_ordenados.index, total_reviews_ordenados["reviews"])
plt.title("Número de reviews")
# Out:
# Text(0.5, 1.0, 'Número de reviews')

# %%
barrios = df_def["Barrio más frecuente"].value_counts()
plt.xticks(rotation=90)
plt.bar(barrios.index, barrios.values)
plt.title("Apariciones de cada barrio")
# Out:
# Text(0.5, 1.0, 'Apariciones de cada barrio')

# %%
plt.subplot(1,3,1)
plt.boxplot(df_def["MP rating"])
plt.scatter(np.ones(len(df_def["MP rating"])), df_def["MP rating"], alpha=0.6, color='red', s=5)
plt.title("MP rating")
plt.subplot(1,3,2)
plt.boxplot(df_def["reviews"])
plt.scatter(np.ones(len(df_def["reviews"])), df_def["reviews"], alpha=0.6, color='red', s=5)
plt.title("Reviews")
plt.subplot(1,3,3)
plt.boxplot(df_def["total"])
plt.scatter(np.ones(len(df_def["total"])), df_def["total"], alpha=0.6, color='red', s=5)
plt.title("Total")
# Out:
# Text(0.5, 1.0, 'Total')
