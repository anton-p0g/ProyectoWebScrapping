# %%
import pandas as pd 
import numpy as np
data = pd.read_csv("restaurantes_con_distrito_barrio.csv")
data

# %%
areas = data
areas = areas.dropna()
areas
# Out:
#       id                           Name  \
# 0      1            Freedom Cakes Diner
# 1      2         Mad Mad Vegan - Chueca
# 2      3              Frutas Prohibidas
# 3      4       Mad Mad Vegan - Lavapiés
# 4      5                  Flower Burger
# ..   ...                            ...
# 719  719                 MAD - Breadway
# 736  736            MAD - La Place - T1
# 737  737                 Chök - Barajas
# 739  739               MAD - Kirei - T4
# 740  740  MAD - Lavazza Espression - T1
#
#                                                Address        Lat      Long  \
# 0                     Calle Cádiz 7,Madrid,Spain,28004  40.415876 -3.702805
# 1                   Calle Pelayo 19,Madrid,Spain,28004  40.422698 -3.698609
# 2         Calle del Conde Duque, 26,Madrid,Spain,28015  40.427467 -3.710349
# 3                       Lavapiés 16,Madrid,Spain,28012  40.411113 -3.703039
# 4        Calle Luchana 13, Chamberí,Madrid,Spain,28010  40.430001 -3.701037
# ...

# %%
datos_necesarios = areas[["Lat", "Long", "Number of Ratings", "Restaurant Rating", "Number of Bookmarks", "Price Range", "NOMBRE_DISTRITO", "NOMBRE_BARRIO"]]
datos_necesarios
# Out:
#            Lat      Long  Number of Ratings  Restaurant Rating  \
# 0    40.415876 -3.702805              470.0                4.5
# 1    40.422698 -3.698609              410.0                5.0
# 2    40.427467 -3.710349              241.0                5.0
# 3    40.411113 -3.703039              216.0                4.5
# 4    40.430001 -3.701037               14.0                4.5
# ..         ...       ...                ...                ...
# 719  40.472222 -3.570932                1.0                3.0
# 736  40.489515 -3.564276                1.0                1.0
# 737  40.489562 -3.564313                1.0                4.0
# 739  40.498332 -3.567598                5.0                4.0
# 740  40.498332 -3.567598                0.0                0.0
#
#      Number of Bookmarks     Price Range NOMBRE_DISTRITO NOMBRE_BARRIO
# 0                    766        Moderado          Centro           Sol
# ...

# %%
datos_necesarios = datos_necesarios[datos_necesarios["Price Range"] != "No price range"]
datos_necesarios.index = np.arange(0,518)
datos_necesarios
# Out:
#            Lat      Long  Number of Ratings  Restaurant Rating  \
# 0    40.415876 -3.702805              470.0                4.5
# 1    40.422698 -3.698609              410.0                5.0
# 2    40.427467 -3.710349              241.0                5.0
# 3    40.411113 -3.703039              216.0                4.5
# 4    40.430001 -3.701037               14.0                4.5
# ..         ...       ...                ...                ...
# 513  40.469377 -3.569407                1.0                3.0
# 514  40.472222 -3.570932                1.0                3.0
# 515  40.489515 -3.564276                1.0                1.0
# 516  40.498332 -3.567598                5.0                4.0
# 517  40.498332 -3.567598                0.0                0.0
#
#      Number of Bookmarks Price Range NOMBRE_DISTRITO NOMBRE_BARRIO
# 0                    766    Moderado          Centro           Sol
# 1                    612    Moderado          Centro      Justicia
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

modelo = MinMaxScaler(feature_range=(0, 1))
datos_necesarios["Number of Ratings"] = modelo.fit_transform(datos_necesarios[["Number of Ratings"]])
datos_necesarios["Number of Bookmarks"] = modelo.fit_transform(datos_necesarios[["Number of Bookmarks"]])
datos_necesarios
# Out:
# C:\Users\josej\AppData\Local\Temp\ipykernel_21852\1901368653.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_necesarios["Number of Ratings"] = modelo.fit_transform(datos_necesarios[["Number of Ratings"]])
# C:\Users\josej\AppData\Local\Temp\ipykernel_21852\1901368653.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_necesarios["Number of Bookmarks"] = modelo.fit_transform(datos_necesarios[["Number of Bookmarks"]])
# ...

# %%
import matplotlib.pyplot as plt

ratings = datos_necesarios["Restaurant Rating"].sort_values()
bins = [0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5]
ratings.plot(kind="hist", bins=bins)
# Out:
# <Axes: ylabel='Frequency'>

# %%
def number_price(x):
    if x == "Moderado":
        return 2
    elif x == "Barato":
        return 1
    else:
        return 3
datos_necesarios["Price Range"] = datos_necesarios["Price Range"].map(number_price)

# %%
datos_necesarios["Restaurant Rating"] = modelo.fit_transform(datos_necesarios[["Restaurant Rating"]])
datos_necesarios
# Out:
# C:\Users\josej\AppData\Local\Temp\ipykernel_21852\2174878600.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_necesarios["Restaurant Rating"] = modelo.fit_transform(datos_necesarios[["Restaurant Rating"]])
#            Lat      Long  Number of Ratings  Restaurant Rating  \
# 0    40.415876 -3.702805           1.000000                0.9
# 1    40.422698 -3.698609           0.872340                1.0
# 2    40.427467 -3.710349           0.512766                1.0
# 3    40.411113 -3.703039           0.459574                0.9
# 4    40.430001 -3.701037           0.029787                0.9
# ..         ...       ...                ...                ...
# 513  40.469377 -3.569407           0.002128                0.6
# ...

# %%
datos_necesarios["Lat"] = modelo.fit_transform(datos_necesarios[["Lat"]])
datos_necesarios["Long"] = modelo.fit_transform(datos_necesarios[["Long"]])
datos_necesarios
# Out:
# C:\Users\josej\AppData\Local\Temp\ipykernel_21852\1112958102.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_necesarios["Lat"] = modelo.fit_transform(datos_necesarios[["Lat"]])
# C:\Users\josej\AppData\Local\Temp\ipykernel_21852\1112958102.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_necesarios["Long"] = modelo.fit_transform(datos_necesarios[["Long"]])
#           Lat      Long  Number of Ratings  Restaurant Rating  \
# ...

# %%
grupo_distrito = datos_necesarios.groupby("NOMBRE_DISTRITO").size()
grupo_distrito_bueno = grupo_distrito[grupo_distrito<=100]
lista_bueno_split = list(grupo_distrito_bueno.index)
print(lista_bueno_split)
grupo_distrito_demasiado = grupo_distrito[grupo_distrito>100]
lista_distritos_split = list(grupo_distrito_demasiado.index)
print(lista_distritos_split)
# Out:
# ['Arganzuela', 'Barajas', 'Carabanchel', 'Chamartin', 'Chamberi', 'Ciudad Lineal', 'Fuencarral-El Pardo', 'Hortaleza', 'Latina', 'Moncloa-Aravaca', 'Moratalaz', 'Puente de Vallecas', 'Retiro', 'Salamanca', 'San Blas - Canillejas', 'Tetuan', 'Usera', 'Vicalvaro', 'Villa de Vallecas']
# ['Centro']

# %%
lista_barrios = []
for distrito in lista_distritos_split:
    restaurantes_distrito = datos_necesarios[datos_necesarios["NOMBRE_DISTRITO"] == distrito]
    grupo_barrio = restaurantes_distrito.groupby("NOMBRE_BARRIO").size()
    lista_barrios = lista_barrios + list(grupo_barrio.index)
    print(grupo_barrio)

print(lista_barrios)
# Out:
# NOMBRE_BARRIO
# Cortes         31
# Embajadores    77
# Justicia       54
# Palacio        30
# Sol            27
# Universidad    62
# dtype: int64
# ['Cortes', 'Embajadores', 'Justicia', 'Palacio', 'Sol', 'Universidad']

# %%
juntar_distritos = {"Arganzuela": ["Arganzuela"], 
                    "Chamberi": ["Chamberi"], 
                    "Salamanca": ["Salamanca"], 
                    "Sector_Norte": ["Fuencarral-El Pardo", "Barajas", "Chamartin", "Hortaleza", "Tetuan"],
                    "Sector_Sureste": ["Ciudad Lineal", "Moratalaz", "Villa de Vallecas", "Vicalvaro", "Puente de Vallecas", "Retiro", "San Blas - Canillejas"],
                    "Sector_Suroreste": ["Carabanchel", "Latina", "Moncloa-Aravaca", "Usera"]}



diccionario_grupos = {}
for distrito in juntar_distritos:
    data_frame = datos_necesarios[datos_necesarios["NOMBRE_DISTRITO"].apply(lambda x: x in juntar_distritos[distrito])]
    data_frame.index = np.arange(0, len(data_frame))
    data_frame["Famous ratio"] = modelo.fit_transform(pd.DataFrame(data_frame["Number of Ratings"] * data_frame["Restaurant Rating"] + data_frame["Number of Bookmarks"]))
    data_frame["Famous ratio"] = data_frame["Famous ratio"] * data_frame["Price Range"]
    minimo = data_frame["Famous ratio"].min()
    maximo = data_frame["Famous ratio"].max()
    intervalo = maximo - minimo
    def calificacion(x):
        if minimo <= x < minimo + (intervalo/3):
            return 1
        elif minimo + (intervalo/3) <= x < minimo + 2*(intervalo/3):
            return 2
        else:
            return 3
    data_frame["quality_classification"] = datos_necesarios["Famous ratio"].map(calificacion)
    diccionario_grupos[distrito] = data_frame
diccionario_grupos["Sector_Norte"]
# Out:
# C:\Users\josej\AppData\Local\Temp\ipykernel_21852\2794100221.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame["Famous ratio"] = modelo.fit_transform(pd.DataFrame(data_frame["Number of Ratings"] * data_frame["Restaurant Rating"] + data_frame["Number of Bookmarks"]))
# C:\Users\josej\AppData\Local\Temp\ipykernel_21852\2794100221.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame["Famous ratio"] = data_frame["Famous ratio"] * data_frame["Price Range"]
# ...

# %%
for barrio in lista_barrios:
    data_frame = datos_necesarios[datos_necesarios["NOMBRE_BARRIO"]==barrio]
    data_frame.index = np.arange(0,len(data_frame))
    data_frame["Famous ratio"] = modelo.fit_transform(pd.DataFrame(data_frame["Number of Ratings"] * data_frame["Restaurant Rating"] + data_frame["Number of Bookmarks"]))
    data_frame["Famous ratio"] = data_frame["Famous ratio"] * data_frame["Price Range"]
    minimo = data_frame["Famous ratio"].min()
    maximo = data_frame["Famous ratio"].max()
    intervalo = maximo - minimo
    def calificacion(x):
        if minimo <= x < minimo + (intervalo/3):
            return 1
        elif minimo + (intervalo/3) <= x < minimo + 2*(intervalo/3):
            return 2
        else:
            return 3
    data_frame["quality_classification"] = datos_necesarios["Famous ratio"].map(calificacion)
    diccionario_grupos[barrio] = data_frame
# Out:
# C:\Users\josej\AppData\Local\Temp\ipykernel_21852\241662833.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame["Famous ratio"] = modelo.fit_transform(pd.DataFrame(data_frame["Number of Ratings"] * data_frame["Restaurant Rating"] + data_frame["Number of Bookmarks"]))
# C:\Users\josej\AppData\Local\Temp\ipykernel_21852\241662833.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame["Famous ratio"] = data_frame["Famous ratio"] * data_frame["Price Range"]
# ...

# %%
for grupo in diccionario_grupos:    
    print(grupo)
# Out:
# Arganzuela
# Chamberi
# Salamanca
# Sector_Norte
# Sector_Sureste
# Sector_Suroreste
# Cortes
# Embajadores
# Justicia
# Palacio
# Sol
# Universidad

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
maximo = barrio["Potencial"].max()
minimo = barrio["Potencial"].min()
cuarta = (maximo-minimo)/4

def colorear(x):
    if minimo <= x < minimo + cuarta:
        return "red"
    elif minimo + cuarta <= x < minimo + 2*cuarta:
        return "blue"
    elif minimo + 2*cuarta <= x < minimo + 3*cuarta:
        return "green"
    else:
        return "purple"

def quality(x):
    if x == 1:
        return "triangulo"
    elif x == 2:
        return "cuadrado"
    else:
        return "pentagono"

barrio["color"] = barrio["Potencial"].map(colorear)
# Crear un gráfico de dispersión para las pelotas
plt.scatter(np.array(data_frame_barrio["Long"]), np.array(data_frame_barrio["Lat"]), c=np.array(barrio["color"]),alpha=0.6, edgecolors="w", linewidth=1)

for i in range(len(barrio)):
    if quality(barrio.loc[i,"quality_classification"]) == "triangulo":
        polygon = plt.Polygon([(barrio.loc[i,"Long"]-0.001, barrio.loc[i, "Lat"]-0.001), 
                               (barrio.loc[i,"Long"]+0.001, barrio.loc[i, "Lat"]-0.001), 
                               (barrio.loc[i,"Long"], barrio.loc[i, "Lat"]+0.001)], closed=True, fill=None, edgecolor='k')
        plt.gca().add_patch(polygon)
    elif quality(barrio.loc[i,"quality_classification"]) == "cuadrado":
        polygon = plt.Polygon([(barrio.loc[i,"Long"]-0.001, barrio.loc[i, "Lat"]-0.001), 
                               (barrio.loc[i,"Long"]+0.001, barrio.loc[i, "Lat"]-0.001), 
                               (barrio.loc[i,"Long"]+0.001, barrio.loc[i, "Lat"]+0.001), 
                               (barrio.loc[i,"Long"]-0.001, barrio.loc[i, "Lat"]+0.001)], closed=True, fill=None, edgecolor='k')
        plt.gca().add_patch(polygon)
    else:
        polygon = plt.Polygon([(barrio.loc[i,"Long"], barrio.loc[i, "Lat"]+0.001),
                               (barrio.loc[i,"Long"]-0.001, barrio.loc[i, "Lat"]+0.0005), 
                               (barrio.loc[i,"Long"]-0.0005, barrio.loc[i, "Lat"]-0.001), 
                               (barrio.loc[i,"Long"]+0.0005, barrio.loc[i, "Lat"]-0.001), 
                               (barrio.loc[i,"Long"]+0.001, barrio.loc[i, "Lat"]+0.00025)], closed=True, fill=None, edgecolor='k')
        plt.gca().add_patch(polygon)

center_x = np.mean(data_frame_barrio["Long"])
center_y = np.mean(data_frame_barrio["Lat"])

# Crear las rectas ajustadas al centro
# Ajuste de las rectas, desplazando hacia el centro
x = np.linspace(-1, 1, 10000)  # Definir el rango de X para las rectas
y1 = V[0, 1] / V[0, 0] * x + center_y - (V[0, 1] / V[0, 0]) * center_x  # Ajustar recta 1
y2 = V[1, 0] / V[1, 1] * x + center_y - (V[1, 0] / V[1, 1]) * center_x  # Ajustar recta 2

plt.plot(x, y1, color="blue")
plt.plot(x, y2, color="red")

# Ajustar los límites de los ejes
plt.xlim(np.min(data_frame_barrio["Long"])-0.005, np.max(data_frame_barrio["Long"])+0.005)
plt.ylim(np.min(data_frame_barrio["Lat"])-0.005, np.max(data_frame_barrio["Lat"])+0.005)

# Añadir título y etiquetas
plt.title("Gráfica de Pelotas en Matplotlib")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.savefig(f'{diccionario_grupos[grupo]}.png')
# Out:
# C:\Users\josej\AppData\Local\Temp\ipykernel_21852\4114731011.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   barrio["color"] = barrio["Potencial"].map(colorear)
# Text(0, 0.5, 'Eje Y')

# %%
for grupo in diccionario_grupos:
    barrio = diccionario_grupos[grupo]
    data_frame_barrio = barrio[["Lat", "Long"]]
    matriz_barrio = np.asmatrix(data_frame_barrio)

    [U, S, V] = np.linalg.svd(matriz_barrio)

    area_dominio_cada_barrio = np.array([])
    for i in range(matriz_barrio.shape[0]):
        barrio_i = matriz_barrio[i,:]
        potencial = np.linalg.norm(matriz_barrio-barrio_i)
        area_dominio_cada_barrio = np.append(area_dominio_cada_barrio, potencial)
    area_dominio_cada_barrio = pd.Series(area_dominio_cada_barrio)
    barrio["Potencial"] = area_dominio_cada_barrio
    plt.figure(figsize=(6,6))
    maximo = barrio["Potencial"].max()
    minimo = barrio["Potencial"].min()
    cuarta = (maximo-minimo)/4

    def colorear(x):
        if minimo <= x < minimo + cuarta:
            return "red"
        elif minimo + cuarta <= x < minimo + 2*cuarta:
            return "blue"
        elif minimo + 2*cuarta <= x < minimo + 3*cuarta:
            return "green"
        else:
            return "purple"

    def quality(x):
        if x == 1:
            return "triangulo"
        elif x == 2:
            return "cuadrado"
        else:
            return "pentagono"

    barrio["color"] = barrio["Potencial"].map(colorear)
    # Crear un gráfico de dispersión para las pelotas
    plt.scatter(np.array(data_frame_barrio["Long"]), np.array(data_frame_barrio["Lat"]), c=np.array(barrio["color"]),alpha=0.6, edgecolors="w", linewidth=1)

    for i in range(len(barrio)):
        if quality(barrio.loc[i,"quality_classification"]) == "triangulo":
            polygon = plt.Polygon([(barrio.loc[i,"Long"]-0.001, barrio.loc[i, "Lat"]-0.001), 
                                (barrio.loc[i,"Long"]+0.001, barrio.loc[i, "Lat"]-0.001), 
                                (barrio.loc[i,"Long"], barrio.loc[i, "Lat"]+0.001)], closed=True, fill=None, edgecolor='k')
            plt.gca().add_patch(polygon)
        elif quality(barrio.loc[i,"quality_classification"]) == "cuadrado":
            polygon = plt.Polygon([(barrio.loc[i,"Long"]-0.001, barrio.loc[i, "Lat"]-0.001), 
                                (barrio.loc[i,"Long"]+0.001, barrio.loc[i, "Lat"]-0.001), 
                                (barrio.loc[i,"Long"]+0.001, barrio.loc[i, "Lat"]+0.001), 
                                (barrio.loc[i,"Long"]-0.001, barrio.loc[i, "Lat"]+0.001)], closed=True, fill=None, edgecolor='k')
            plt.gca().add_patch(polygon)
        else:
            polygon = plt.Polygon([(barrio.loc[i,"Long"], barrio.loc[i, "Lat"]+0.001),
                                (barrio.loc[i,"Long"]-0.001, barrio.loc[i, "Lat"]+0.0005), 
                                (barrio.loc[i,"Long"]-0.0005, barrio.loc[i, "Lat"]-0.001), 
                                (barrio.loc[i,"Long"]+0.0005, barrio.loc[i, "Lat"]-0.001), 
                                (barrio.loc[i,"Long"]+0.001, barrio.loc[i, "Lat"]+0.00025)], closed=True, fill=None, edgecolor='k')
            plt.gca().add_patch(polygon)

    center_x = np.mean(data_frame_barrio["Long"])
    center_y = np.mean(data_frame_barrio["Lat"])

    # Crear las rectas ajustadas al centro
    # Ajuste de las rectas, desplazando hacia el centro
    x = np.linspace(-1, 1, 10000)  # Definir el rango de X para las rectas
    y1 = V[0, 1] / V[0, 0] * x + center_y - (V[0, 1] / V[0, 0]) * center_x  # Ajustar recta 1
    y2 = V[1, 0] / V[1, 1] * x + center_y - (V[1, 0] / V[1, 1]) * center_x  # Ajustar recta 2

    plt.plot(x, y1, color="blue")
    plt.plot(x, y2, color="red")

    # Ajustar los límites de los ejes
    plt.xlim(np.min(data_frame_barrio["Long"])-0.005, np.max(data_frame_barrio["Long"])+0.005)
    plt.ylim(np.min(data_frame_barrio["Lat"])-0.005, np.max(data_frame_barrio["Lat"])+0.005)

    # Añadir título y etiquetas
    plt.title("Gráfica de Pelotas en Matplotlib")
    plt.xlabel("Eje X")
    plt.ylabel("Eje Y")
    plt.savefig(f'{grupo}.png')
# Out:
# C:\Users\josej\AppData\Local\Temp\ipykernel_21852\872993409.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   barrio["Potencial"] = area_dominio_cada_barrio
# C:\Users\josej\AppData\Local\Temp\ipykernel_21852\872993409.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   barrio["color"] = barrio["Potencial"].map(colorear)
# C:\Users\josej\AppData\Local\Temp\ipykernel_21852\872993409.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
